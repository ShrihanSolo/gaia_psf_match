# %%
from astropy.io import fits
import pandas as pd
from astropy.coordinates import SkyCoord
import astropy.units as u
import matplotlib.pyplot as plt
import numpy as np
from scipy.cluster.vq import vq, kmeans
import scipy
from astroquery.gaia import Gaia
import os

import match

# Global Parameters
BAND = 'i'
PSF_DATA_FILEPATH = "../../psf_data/psf_y3a1-v29.fits"
RESULTS_FILEPATH = "../results/"
TOTAL_SUBSAMPLE_SIZE = 10000
CLUSTER_SUBSAMPLE_SIZE = 1000
NUMBER_OF_CLUSTERS = 100
MATCH_LIM = 1 * u.arcsec
INT_DATA_PATH = "../../int_data/"

# %%
def read_des_fits(file_path, band, n = int(1e6)):
    """
    Read in the DES fits file and return a pandas dataframe with ra, dec, mag and band columns.
    Args: 
        file_path: path to the fits file
        band: band to be read in
        n: subsample of stars to be read in within specified band
    Returns:
        des: pandas dataframe with ra, dec, mag and band columns
    """
    
    # Read in the fits file and close it
    hdul = fits.open(file_path)
    
    # hdul[1].data is a numpy recarray. Get the ra, dec, mag and band columns   
    cols = ['ra', 'dec', 'mag', 'band']
    zidx = np.random.choice(np.where(hdul[1].data['band'] == band)[0], size = n, replace = False)
    data = {col: hdul[1].data[col][zidx] for col in cols}
    hdul.close()

    des = pd.DataFrame(data)
    

    # Combine ra and dec into a sky coord array
    des['coord'] = SkyCoord(ra=des['ra'], dec=des['dec'], unit = 'deg')
    return des

print("Starting DES Gaia Crossmatch for Band " + str(BAND) + ".")

# Read in DES Data
des = read_des_fits(PSF_DATA_FILEPATH, BAND, n = TOTAL_SUBSAMPLE_SIZE)
print("Data read in.")
# Out:
# Starting DES Gaia Crossmatch for Band i.
# Data read in.

# %%
# Plot location of subsample of PSF stars
match.plot_sanity_test(des['coord'], fold = RESULTS_FILEPATH, BAND = BAND)

# %%
# Perform clustering on subsample of PSF stars, use on full sample
centroids = match.perform_clustering(des, NUMBER_OF_CLUSTERS, CLUSTER_SUBSAMPLE_SIZE)
# Out:
# Centroids found.

# %%
# Save centroids array to int_data
np.save(INT_DATA_PATH + "centroids.npy", centroids)

# %%
# Load centroids array from int_data
centroids = np.load(INT_DATA_PATH + "centroids.npy")

# %%
cluster_num_array, cluster_info = match.get_assignments(des, centroids)
# Out:
# Stars clustered.

# %%
# Plot the clusters with color
ra_dec = np.array([des['ra'], des['dec']]).T
match.plot_cluster_test(ra_dec, centroids, cluster_num_array, fold = RESULTS_FILEPATH, BAND = BAND)

# %%
for cluster_num in range(NUMBER_OF_CLUSTERS):
    clust0_info = cluster_info.loc[cluster_num]
    print("R = {:.3f}".format(clust0_info["max_dist"]), end = ' | ')
    gaia0_tab = query_gaia_for_cluster(clust0_info["centroids"][0], 
                                       clust0_info["centroids"][1], 
                                       clust0_info["max_dist"],
                                       verbose=True)
    print("Queried.", end = ' ')
    
    # Save the gaia table in int_data
    gaia0_tab.write(INT_DATA_PATH + "gaia/" + "gaia" + str(i) + ".fits", overwrite = True)

# %%
# Match Gaia for stars in the clusters 
for i in range(NUMBER_OF_CLUSTERS):
    print("Cluster " + str(i) + ":", end = ' ')
    comb_clusteri = match.match_cluster_to_gaia(des, cluster_num_array, ra_dec, cluster_info, i)
    print("Matched.")
    comb_clusteri.to_csv(INT_DATA_PATH + "cluster_" + str(BAND) + "_" + str(i) + ".csv")
# Out:
# Cluster 0: R = 1.593 | Queried. Matched.
# Cluster 1: R = 3.447 |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/shrihan/weaklens/gaia_match_psf/gaia_match_psf_code/src/main_test.ipynb Cell 6 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2Bmidway3.rcc.uchicago.edu/home/shrihan/weaklens/gaia_match_psf/gaia_match_psf_code/src/main_test.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> for i in range(NUMBER_OF_CLUSTERS):
#       <a href='vscode-notebook-cell://ssh-remote%2Bmidway3.rcc.uchicago.edu/home/shrihan/weaklens/gaia_match_psf/gaia_match_psf_code/src/main_test.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     print("Cluster " + str(i) + ":", end = ' ')
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bmidway3.rcc.uchicago.edu/home/shrihan/weaklens/gaia_match_psf/gaia_match_psf_code/src/main_test.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     comb_clusteri = match.match_cluster_to_gaia(des, cluster_num_array, ra_dec, cluster_info, i)
#       <a href='vscode-notebook-cell://ssh-remote%2Bmidway3.rcc.uchicago.edu/home/shrihan/weaklens/gaia_match_psf/gaia_match_psf_code/src/main_test.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     print("Matched.")
#       <a href='vscode-notebook-cell://ssh-remote%2Bmidway3.rcc.uchicago.edu/home/shrihan/weaklens/gaia_match_psf/gaia_match_psf_code/src/main_test.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     comb_clusteri.to_csv(INT_DATA_PATH + "cluster_" + str(BAND) + "_" + str(i) + ".csv")
#
# File ~/weaklens/gaia_match_psf/gaia_match_psf_code/src/match.py:217, in match_cluster_to_gaia(data, cluster_num_array, ra_dec, cluster_info, cluster_num, MATCH_LIM)
#     215 clust0_info = cluster_info.loc[cluster_num]
#     216 print("R = {:.3f}".format(clust0_info["max_dist"]), end = ' | ')
# --> 217 gaia0_tab = query_gaia_for_cluster(clust0_info["centroids"][0], clust0_info["centroids"][1], clust0_info["max_dist"])
#     219 print("Queried.", end = ' ')
#     221 cluster0 = SkyCoord(ra_dec[cluster_num_array[0] == cluster_num] * u.deg)
#
# File ~/weaklens/gaia_match_psf/gaia_match_psf_code/src/match.py:188, in query_gaia_for_cluster(ra, dec, dist, lim, verbose)
#     186 if verbose:
#     187     print(query)
# --> 188 job = Gaia.launch_job(query, dump_to_file=True)
#     189 result_table = job.get_results()
#     190 gaia_table = result_table.to_pandas()
#
# File ~/.conda/envs/weaklens2/lib/python3.10/site-packages/astroquery/gaia/core.py:854, in GaiaClass.launch_job(self, query, name, output_file, output_format, verbose, dump_to_file, upload_resource, upload_table_name)
#     819 def launch_job(self, query, name=None, output_file=None,
#     820                output_format="votable", verbose=False,
#     821                dump_to_file=False, upload_resource=None,
#     822                upload_table_name=None):
#     823     """Launches a synchronous job
#     824
#     825     Parameters
#    (...)
#     851     A Job object
#     852     """
# --> 854     return TapPlus.launch_job(self, query=query, name=name,
#     855                               output_file=output_file,
#     856                               output_format=output_format,
#     857                               verbose=verbose,
#     858                               dump_to_file=dump_to_file,
#     859                               upload_resource=upload_resource,
#     860                               upload_table_name=upload_table_name)
#
# File ~/.conda/envs/weaklens2/lib/python3.10/site-packages/astroquery/utils/tap/core.py:285, in Tap.launch_job(self, query, name, output_file, output_format, verbose, dump_to_file, upload_resource, upload_table_name)
#     277     response = self.__launchJobMultipart(query,
#     278                                          upload_resource,
#     279                                          upload_table_name,
#    (...)
#     282                                          verbose,
#     283                                          name)
#     284 else:
# --> 285     response = self.__launchJob(query,
#     286                                 output_format,
#     287                                 "sync",
#     288                                 verbose,
#     289                                 name)
#     290 # handle redirection
#     291 if response.status == 303:
#     292     # redirection
#
# File ~/.conda/envs/weaklens2/lib/python3.10/site-packages/astroquery/utils/tap/core.py:625, in Tap.__launchJob(self, query, outputFormat, context, verbose, name, autorun)
#     623     args['jobname'] = name
#     624 data = self.__connHandler.url_encode(args)
# --> 625 response = self.__connHandler.execute_tappost(subcontext=context,
#     626                                               data=data,
#     627                                               verbose=verbose)
#     628 if verbose:
#     629     print(response.status, response.reason)
#
# File ~/.conda/envs/weaklens2/lib/python3.10/site-packages/astroquery/utils/tap/conn/tapconn.py:273, in TapConn.execute_tappost(self, subcontext, data, content_type, verbose)
#     252 """Executes a POST request
#     253 The connection is done through HTTP or HTTPS depending on the login
#     254 status (logged in -> HTTPS)
#    (...)
#     270 An HTTP(s) response object
#     271 """
#     272 context = self.__get_tap_context(subcontext)
# --> 273 return self.__execute_post(context, data, content_type, verbose)
#
# File ~/.conda/envs/weaklens2/lib/python3.10/site-packages/astroquery/utils/tap/conn/tapconn.py:427, in TapConn.__execute_post(self, context, data, content_type, verbose)
#     425 self.__postHeaders["Content-type"] = content_type
#     426 conn.request("POST", context, data, self.__postHeaders)
# --> 427 response = conn.getresponse()
#     428 self.__currentReason = response.reason
#     429 self.__currentStatus = response.status
#
# File ~/.conda/envs/weaklens2/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/.conda/envs/weaklens2/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.conda/envs/weaklens2/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.conda/envs/weaklens2/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.conda/envs/weaklens2/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.conda/envs/weaklens2/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Concatenate all the clusters
master_comb_df = match.concatenate_int_data(INT_DATA_PATH)
master_comb_df.to_csv(RESULTS_FILEPATH + "DES_MATCH_BAND" + str(BAND) + ".csv")
print("Concatenated Master DF.")
# Out:
# Concatenated Master DF.

# %%
master_comb_df = pd.read_csv(RESULTS_FILEPATH + "DES_MATCH_BAND" + str(BAND) + ".csv")

# %%
# Plot matching tests and results
match.sanity_separation_test(master_comb_df, fold = RESULTS_FILEPATH, BAND = BAND)
match.plot_match_completeness(master_comb_df, fold = RESULTS_FILEPATH, BAND = BAND)
match.galaxy_ratio_plot(master_comb_df, fold = RESULTS_FILEPATH, BAND = BAND)
print("Plotting Complete.")
# Out:
# /home/shrihan/weaklens/gaia_match_psf/gaia_match_psf_code/src/match.py:299: RuntimeWarning: invalid value encountered in divide
#   plt.bar(mid(failed_star_galaxy_cut[1]), failed_star_galaxy_cut[0] / all_match[0], label = "Fraction Matched Failing Star-Galaxy Cut",color = "orange", width=0.14)
# /home/shrihan/weaklens/gaia_match_psf/gaia_match_psf_code/src/match.py:300: RuntimeWarning: invalid value encountered in divide
#   plt.bar(mid(galaxy_match[1]), galaxy_match[0] / all_match[0], label = "Fraction Matched Gaia Galaxy Candidates",color = "green", width=0.14)
# /home/shrihan/weaklens/gaia_match_psf/gaia_match_psf_code/src/match.py:308: RuntimeWarning: invalid value encountered in divide
#   plt.bar(mid(failed_star_galaxy_cut[1]), failed_star_galaxy_cut[0] / all_match[0], label = "Fraction Matched Failing Star-Galaxy Cut",color = "orange", width=0.14)
# /home/shrihan/weaklens/gaia_match_psf/gaia_match_psf_code/src/match.py:309: RuntimeWarning: invalid value encountered in divide
#   plt.bar(mid(galaxy_match[1]), galaxy_match[0] / all_match[0], label = "Fraction Matched Gaia Galaxy Candidates",color = "green", width=0.14)
# Plotting Complete.
